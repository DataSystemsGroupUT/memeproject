# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import requests
from PIL import Image
from IPython.display import display, Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img_data = requests.get("https://imgflip.com/s/meme/Blank-Nut-Button.jpg").content
with open('input.jpg', 'wb') as handler:
    handler.write(img_data)

# %%
# show the input image
display(Image(filename='input.jpg'))

# %%
# captioning the meme by using dankcli package
# !python -m dankcli "input.jpg" "Meme text you want to add" -f "output"
# Out:
# Saved as output.jpg

# %%
# show the output image after captioning the meme
display(Image(filename='output.jpg'))
